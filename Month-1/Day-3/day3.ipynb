# %% [markdown]
# #BOOLEAN LOGIC
# A Boolean value is either:
#
# True
# False
#
# Everything in decision making comes down to one question:
#
# Is this condition True or False?

# %%
age = 20
print(age<10)
# Out:
# False

# %% [markdown]
# #COMPARISON OPERATORS
# Know these by heart:
#
# Operator	Meaning
# ==	        Equal
# !=	       Not equal
# >	       Greater than
# <	       Less than
# >=	       Greater than or equal
# <=	        Less than or equal

# %%
age=10
print(age==10)
# Out:
# True

# %% [markdown]
# #if, elif, else

# %%
age =20
if age>=18:
    print("Eligible to vote")
else:
    print("Minor")
# Out:
# Eligible to vote

# %%
marks= 75

if marks>=90:
    print("Excellent")
elif marks<=80:
    print("Good")
elif marks<=70:
    print("Average")
else:
    print("Work Harder")
# Out:
# Good

# %% [markdown]
# #LOGICAL OPERATORS
#
# AND, OR, NOT

# %%
age = 20
has_id = True
if age>=18 and has_id
